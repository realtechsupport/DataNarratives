# %%
#getting started with matlib plots

#import a plotting library
import matplotlib
import matplotlib.pyplot as plt

#make some fake data
x = [1,1,2,3,1,2,3,5,6,7,3,8,6,7]

#issue plot commands
plt.plot(x)
plt.show()

# %%
#stylesheets
#https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.11-Settings-and-Stylesheets.ipynb

print(plt.style.available[:10])

plt.style.use('classic')
plt.plot(x, 'o')
plt.plot(x, linestyle='--', markersize=1)
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot(x, 'o')
plt.plot(x, linestyle='--', markersize=1)
plt.show()

# %%
plt.style.use('seaborn-pastel')
plt.plot(x, 'o')
plt.plot(x, linestyle='--', markersize=1)
plt.show()

# %%
# manual customization
#use a different color
#https://matplotlib.org/3.3.2/tutorials/colors/colors.html
plt.plot(x, 'g')
plt.show()

# %%
# manual customization
#use a different line style
#https://www.delftstack.com/howto/matplotlib/linestyles-in-matplotlib-python/
plt.plot(x, 'g', linestyle='--')
plt.show()

# %%
# manual customization
#add a grid
plt.plot(x, 'g', linestyle='--')
plt.grid()
plt.show()

# %%
# manual customization
#add a title
plt.plot(x, 'g', linestyle='--')
plt.grid()
plt.title('funky fake data')
plt.show()

# %%
# manual customization
#add axis labels
plt.plot(x, 'g', linestyle='--')
plt.grid()
plt.title('funky fake data')
plt.xlabel('number of entries')
plt.ylabel('values')
plt.show()

# %%
# manual customization
#change the font size
plt.plot(x, 'g', linestyle='--')
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)
plt.show()

# %%
# manual customization
#change the background color
plt.plot(x, 'g', linestyle='--')
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)
ax = plt.gca()
ax.set_facecolor('lightgray')
plt.show()

# %%
# manual customization
#change the markersize
#https://jakevdp.github.io/PythonDataScienceHandbook/04.02-simple-scatter-plots.html
plt.plot(x, 'o', color='black', markersize=4)
plt.plot(x, 'g', linestyle='--', markersize=1)
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)
ax = plt.gca()
ax.set_facecolor('lightgray')
plt.show()

# %%
# manual customization
#change transparency of background
plt.plot(x, 'o', color='black', markersize=4)
plt.plot(x, 'g', linestyle='--', markersize=1)
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)
ax = plt.gca()
ax.set_facecolor('lightgray')
ax.patch.set_alpha(0.25)
plt.show()

# %%
# manual customization
#add a legend
#https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.legend.html

# %%
#find installed fonts
import matplotlib.font_manager as font_manager
for font in font_manager.findSystemFonts():
  print (font)

# %%
#change a font
#http://www.himpactwxlab.com/home/how-to-wiki/change-matplotlib-fonts

fontpath = '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf'
fonttype = font_manager.FontProperties(fname=fontpath)
matplotlib.rcParams['font.family'] = fonttype.get_name()


plt.plot(x, 'o', color='black', markersize=4, label='datapoints')
plt.plot(x, 'g', linestyle='--', markersize=1)
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)

ax = plt.gca()
ax.set_facecolor('lightgray')
ax.patch.set_alpha(0.25)
ax.legend()
plt.show()

# %%
#fill between graph and x axis 
import matplotlib
import matplotlib.pyplot as plt

#make some fake data
x = [2,3,4,3,6,2,3,5,6,7,3,8,6,7]
x2 = [0,0,3,3,1,2,3,5,3,5,3,3,6,5]

plt.plot(x, 'o', color='black', markersize=4, label='datapoints')
inds = list(range(0, len(x)))
plt.fill_between(inds, x)
plt.fill_between(inds, x2)

plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)

ax = plt.gca()
ax.set_facecolor('lightgray')
ax.patch.set_alpha(0.25)
ax.legend()
plt.show()

# %%
#NEW - now save the file as a jpeg with specified file type and resolution 
plt.plot(x, 'o', color='black', markersize=4, label='datapoints')
inds = list(range(0, len(x)))
plt.fill_between(inds, x)

plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)

ax = plt.gca()
ax.set_facecolor('lightgray')
ax.patch.set_alpha(0.25)
ax.legend()
#-------------------------------------------------------------------------------
# Make sure your drive is mounted
from google.colab import drive
drive.mount('/content/drive')
#change this based on your setup
root = '/content/drive/MyDrive/ART/data_visualization/'
datapath =  root + 'data/'

plt.savefig(datapath + 'hellofakedata_hires.png', dpi = 600, bbox_inches = 'tight')
plt.savefig(datapath + 'hellofakedata_lowres.png', dpi = 72, bbox_inches = 'tight')
plt.show()

# %%
#add a background image
import urllib.request
import matplotlib
import matplotlib.pyplot as plt

#make some fake data
x = [1,1,2,3,1,2,3,5,6,7,3,8,6,7]

#get an image you like
url = 'https://static.beonhome.com/wp-content/uploads/2019/06/Can-Fake-Security-Signs-And-Stickers-Keep-Your-Home-Safe-Find-Out-the-truth-1024x385.jpg'
imagename = 'background.jpg'
urllib.request.urlretrieve(url, imagename)
img = plt.imread(imagename)

#plot the data
plt.plot(x, 'o', color='black', markersize=4, label='datapoints')
plt.plot(x, 'g', linestyle='--', markersize=1)
plt.grid()
plt.title('funky fake data', fontsize=18)
plt.xlabel('number of entries', fontsize=8)
plt.ylabel('values', fontsize=8)

#change the background color
# salmon = (1.0, 0.47, 0.42)
# ax = plt.gca()
# ax.set_facecolor(salmon)

# or add  an image as background
# https://matplotlib.org/3.3.4/gallery/images_contours_and_fields/image_transparency_blend.html
ax = plt.gca()
ax.imshow(img, extent=[0, 13, 0, 10], alpha = 0.5)

#display the figure
plt.figure(figsize=(15,15))
plt.show()

# %%
# do a histogram
import matplotlib.pyplot as plt
import numpy as np

# Use numpy to generate a bunch of random data in a bell curve around 5.
n = 5 + np.random.randn(1000)

m = [m for m in range(len(n))]
plt.plot(m, n, '.')
plt.title("scatter")
plt.show()

plt.bar(m, n)
plt.title("bar")
plt.show()

plt.hist(n, bins=20)
plt.title("histogram")
plt.show()

plt.hist(n, bins=20, edgecolor='black', linewidth=1.2)
plt.title("histogram")
plt.show()

# %%
# !pip install mpld3

# %%
#an advanced interactive example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import mpld3
from mpld3 import plugins
np.random.seed(9615)

# generate df
N = 100
df = pd.DataFrame((.1 * (np.random.random((N, 6)) - .5)).cumsum(0), columns=['a', 'a2', 'a3', 'a4', 'e', 'f'],)
#print(df.head())


# plot line + confidence interval
psize_x = 5
psize_y = 5
alpha_s = 0.2

fig, ax = plt.subplots(figsize=(psize_x,psize_y))
ax.grid(True, alpha=alpha_s)

for key, val in df.iteritems():
     col, = ax.plot(val.index, val.values, label=key)
     ax.fill_between(val.index, val.values * .5, val.values * 1.5, color=col.get_color(), alpha=.4)


# define interactive legend
handles, labels = ax.get_legend_handles_labels() # return lines and labels
interactive_legend = plugins.InteractiveLegendPlugin(zip(handles, ax.collections), labels, alpha_unsel=0.5, alpha_over=1.5, start_visible=True)
plugins.connect(fig, interactive_legend)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Interactive legend', size=20)

#mpld3.show()
mpld3.display()
# Out:
# <style>
#
#     .legend-box {
#       cursor: pointer;
#     }
#
# </style>
#
# <div id="fig_el571399071003186722124809571"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("interactive_legend", InteractiveLegend);
#     InteractiveLegend.prototype = Object.create(mpld3.Plugin.prototype);
#     InteractiveLegend.prototype.constructor = InteractiveLegend;
#     InteractiveLegend.prototype.requiredProps = ["element_ids", "labels"];
#     InteractiveLegend.prototype.defaultProps = {"ax":null,
# ...
